# %% [markdown]
# <a href="https://colab.research.google.com/github/kebora/goelectric/blob/main/electric.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_excel('electric.xlsx')

# %%
df
# Out:
#       Countries  No of Charging ports  Population  % of electric cars
# 0     Argentina                   808       73272                   8
# 1        Norway                   576      467706                   0
# 2      Thailand                   246      301781                   9
# 3         Kenya                   250      112996                  10
# 4     Australia                   147      410806                   4
# ..          ...                   ...         ...                 ...
# 105  Mozambique                   330      160087                   3
# 106    Zimbabwe                    10      288763                   4
# 107    Botswana                   252      428776                  10
# 108      Malawi                   192      328478                   0
# 109      Rwanda                   365      402013                   4
#
# [110 rows x 4 columns]

# %%
df.columns
# Out:
# Index(['Countries', 'No of Charging ports', 'Population',
#        '% of electric cars'],
#       dtype='object')

# %% [markdown]
# **Remove all % of electric cars with a value of 0**

# %%
df = df[df['% of electric cars'] != 0]
df
# Out:
#       Countries  No of Charging ports  Population  % of electric cars
# 0     Argentina                   808       73272                   8
# 2      Thailand                   246      301781                   9
# 3         Kenya                   250      112996                  10
# 4     Australia                   147      410806                   4
# 5        Brazil                   111      425414                   9
# ..          ...                   ...         ...                 ...
# 104  Costa Rica                    41      390018                   5
# 105  Mozambique                   330      160087                   3
# 106    Zimbabwe                    10      288763                   4
# 107    Botswana                   252      428776                  10
# 109      Rwanda                   365      402013                   4
#
# [99 rows x 4 columns]

# %% [markdown]
# #Questions
#
# 1.   What is the correlation between the charging ports and the percentage of electric cars?
# 2.   If I increase the number of charging ports, will the number of electric cars increase?
#
#
# 3.   How is the population of an area linked to the number of charging ports?

# %%
# A chart highlighting No of Charging ports against % of electric cars
# sample any random 20
random_sample_df = df.sample(n=80)
random_sample_df.plot(kind='scatter', x='% of electric cars', y='No of Charging ports', legend=False)
# Out:
# <Axes: xlabel='% of electric cars', ylabel='No of Charging ports'>

# %% [markdown]
# ## Hypothesis
# Number of charging ports are high when the percentage of electric cars is high.

# %% [markdown]
# Make another chart for population against % of electric cars

# %%
random_pop_sample_df = df.sample(n=80)
random_pop_sample_df.plot(kind='scatter', x='% of electric cars', y='Population', legend=False)
# Out:
# <Axes: xlabel='% of electric cars', ylabel='Population'>

# %% [markdown]
# ##Hypothesis
# Population does not seem to be a great factor, maybe the average income, which is not available in the data.
